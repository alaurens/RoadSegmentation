# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from visualization import *
from data_process import *
from paths_to_data import *

# %% [markdown]
# # Loading test images & the prediction images

# %%
# Loading Test images

image_folder = TEST_FOLDER_PATH
files = os.listdir(image_folder)
n = len(files)
print("Loading " + str(n) + " images")
test_images = np.asarray([load_image(image_folder+ "/test_"+str(i)+"/test_"+str(i)+".png") for i in range(1,n)])

#Loading predictions 

image_folder_prediction = PREDICTED_IMAGES_PATH
files_p = os.listdir(image_folder_prediction)
n_p = len(files_p)
print("Loading " + str(n_p) + " images")
prediction_images = np.asarray([load_image(image_folder_prediction+"/prediction"+str(i)+".png") for i in range(1,n_p)])
# Out:
# Loading 51 images
# Loading 51 images

# %% [markdown]
# # Plot of the first image of the data test overlayed with the road prediction

# %%
print(test_images[0].shape)
new_img_1 = make_img_overlay(test_images[0], prediction_images[0])
plt.imshow(new_img_1);
# Out:
# (608, 608, 3)

# %% [markdown]
# # Plot of two test images overlayed with the road prediction

# %%
fig = plt.figure(figsize=(10, 10))
prediction_2_image(9,16)
